# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Final-Engineering" data-toc-modified-id="1.-Final-Engineering-1">1. Final Engineering</a></span><ul class="toc-item"><li><span><a href="#1.1-Feature-Scaling" data-toc-modified-id="1.1-Feature-Scaling-1.1">1.1 Feature Scaling</a></span></li><li><span><a href="#1.2-SMOTE" data-toc-modified-id="1.2-SMOTE-1.2">1.2 SMOTE</a></span></li><li><span><a href="#1.3-Convert-dataframe" data-toc-modified-id="1.3-Convert-dataframe-1.3">1.3 Convert dataframe</a></span></li></ul></li><li><span><a href="#2.-Model(With-outliers)" data-toc-modified-id="2.-Model(With-outliers)-2">2. Model(With outliers)</a></span><ul class="toc-item"><li><span><a href="#2.1-Define-the-Model" data-toc-modified-id="2.1-Define-the-Model-2.1">2.1 Define the Model</a></span></li><li><span><a href="#2.2-Train-the-model(No-SMOTE)" data-toc-modified-id="2.2-Train-the-model(No-SMOTE)-2.2">2.2 Train the model(No SMOTE)</a></span></li><li><span><a href="#2.3-Train-the-model(SMOTE)" data-toc-modified-id="2.3-Train-the-model(SMOTE)-2.3">2.3 Train the model(SMOTE)</a></span></li><li><span><a href="#2.3-Train-the-model(SMOTE)" data-toc-modified-id="2.3-Train-the-model(SMOTE)-2.4">2.3 Train the model(SMOTE)</a></span></li></ul></li><li><span><a href="#3.-Model(No-outliers)" data-toc-modified-id="3.-Model(No-outliers)-3">3. Model(No outliers)</a></span><ul class="toc-item"><li><span><a href="#3.1-Define-the-Model" data-toc-modified-id="3.1-Define-the-Model-3.1">3.1 Define the Model</a></span></li><li><span><a href="#3.2-Train-the-model(SMOTE)" data-toc-modified-id="3.2-Train-the-model(SMOTE)-3.2">3.2 Train the model(SMOTE)</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import OneHotEncoder
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Final Engineering

# %%
df_train = pd.read_pickle('../Data/part2_df_train_outliers.pkl')
df_test = pd.read_pickle('../Data/part2_df_test_outliers.pkl')

# df_train = pd.read_pickle('../Data/part2_df_train_NO_outliers.pkl')
# df_test = pd.read_pickle('../Data/part2_df_test_NO_outliers.pkl')

# %%
X_train = df_train.drop(['loan_status'], axis=1)
y_train = df_train.loc[:, 'loan_status']

X_test = df_test.drop(['loan_status'], axis=1)
y_test = df_test['loan_status']

# %% [markdown]
# ### 1.1 Feature Scaling

# %%
# Create an imputer object with a median filling strategy
scaler = StandardScaler()

# Train on the training features
scaler.fit(X_train)

# Transform both training and testing data
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# ### 1.2 SMOTE

# %%
sm = SMOTE(random_state=12, n_jobs = -1, k_neighbors=5, sampling_strategy='auto')
X_train, y_train = sm.fit_resample(X_train, y_train)

# %% [markdown]
# ### 1.3 Convert dataframe

# %%
# y_train = torch.tensor(y_train.values).flatten()
# y_test = torch.tensor(y_test.values).flatten()
# X_train = torch.tensor(X_train[X_train.columns].values)
# X_test = torch.tensor(X_test[X_test.columns].values)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()
X_train = X_train.to_numpy()
X_test = X_test.to_numpy()

# %% [markdown]
# ## 2. Model(With outliers)

# %% [markdown]
# ### 2.1 Define the Model

# %%
class TabularModel(nn.Module):
    def __init__(self, input_dim):
        super(TabularModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 200)
        self.layer2 = nn.Linear(200, 300)
        self.layer3 = nn.Linear(300, 2)
        
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
model =  TabularModel(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()
model
# Out:
# TabularModel(
#   (layer1): Linear(in_features=118, out_features=200, bias=True)
#   (layer2): Linear(in_features=200, out_features=300, bias=True)
#   (layer3): Linear(in_features=300, out_features=2, bias=True)
# )

# %% [markdown]
# ### 2.2 Train the model(No SMOTE)

# %%
EPOCHS  = 100

X_train = Variable(torch.from_numpy(X_train)).float()
y_train = Variable(torch.from_numpy(y_train)).long()
X_test  = Variable(torch.from_numpy(X_test)).float()
y_test  = Variable(torch.from_numpy(y_test)).long()


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()
    
    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [05:33<00:00,  3.34s/it]

# %%
plt.figure(figsize=(10, 10))
plt.plot([0, 1], [0, 1], 'k--')

# One hot encoding
enc = OneHotEncoder()
Y_onehot = enc.fit_transform(y_test[:, np.newaxis]).toarray()

with torch.no_grad():
    y_pred = model(X_test).numpy()
    fpr, tpr, threshold = roc_curve(Y_onehot.ravel(), y_pred.ravel())
    
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc(fpr, tpr)))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend();

# %% [markdown]
# ### 2.3 Train the model(SMOTE)

# %%
EPOCHS  = 100

X_train = Variable(torch.from_numpy(X_train)).float()
y_train = Variable(torch.from_numpy(y_train)).long()
X_test  = Variable(torch.from_numpy(X_test)).float()
y_test  = Variable(torch.from_numpy(y_test)).long()


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()
    
    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [09:11<00:00,  5.51s/it]

# %%
Y_PRE = torch.from_numpy(y_pred)

# %%
Y_PREDIT = [torch.argmax(Y_PRE, dim=1).type(torch.FloatTensor)]

# %%
Y_PREDIT = np.array(Y_PREDIT)
# Out:
# D:\Temp\ipykernel_12384\2585287670.py:1: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   Y_PREDIT = np.array(Y_PREDIT)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 Y_PREDIT = np.array(Y_PREDIT)
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
from torchmetrics import ConfusionMatrix

# %%
confmat = ConfusionMatrix(num_classes=2)
confmat(Y_PREDIT, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 confmat = ConfusionMatrix(num_classes=2)
# ----> 2 confmat(Y_PREDIT, y_test)
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torch\nn\modules\module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\metric.py:237, in Metric.forward(self, *args, **kwargs)
#     235     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     236 else:
# --> 237     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     239 return self._forward_cache
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\metric.py:301, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     298 self._enable_grad = True  # allow grads for batch computation
#     300 # calculate batch state and compute batch value
# --> 301 self.update(*args, **kwargs)
#     302 batch_val = self.compute()
#     304 # reduce batch and global state
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\metric.py:383, in Metric._wrap_update.<locals>.wrapped_func(*args, **kwargs)
#     381 with torch.set_grad_enabled(self._enable_grad):
#     382     try:
# --> 383         update(*args, **kwargs)
#     384     except RuntimeError as err:
#     385         if "Expected all tensors to be on" in str(err):
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\classification\confusion_matrix.py:124, in ConfusionMatrix.update(self, preds, target)
#     117 def update(self, preds: Tensor, target: Tensor) -> None:  # type: ignore
#     118     """Update state with predictions and targets.
#     119
#     120     Args:
#     121         preds: Predictions from model
#     122         target: Ground truth values
#     123     """
# --> 124     confmat = _confusion_matrix_update(preds, target, self.num_classes, self.threshold, self.multilabel)
#     125     self.confmat += confmat
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\functional\classification\confusion_matrix.py:38, in _confusion_matrix_update(preds, target, num_classes, threshold, multilabel)
#      25 def _confusion_matrix_update(
#      26     preds: Tensor, target: Tensor, num_classes: int, threshold: float = 0.5, multilabel: bool = False
#      27 ) -> Tensor:
#      28     """Updates and returns confusion matrix (without any normalization) based on the mode of the input.
#      29
#      30     Args:
#    (...)
#      35         multilabel: determines if data is multilabel or not.
#      36     """
# ---> 38     preds, target, mode = _input_format_classification(preds, target, threshold)
#      39     if mode not in (DataType.BINARY, DataType.MULTILABEL):
#      40         preds = preds.argmax(dim=1)
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\utilities\checks.py:403, in _input_format_classification(preds, target, threshold, top_k, num_classes, multiclass, ignore_index)
#     322 """Convert preds and target tensors into common format.
#     323
#     324 Preds and targets are supposed to fall into one of these categories (and are
#    (...)
#     400         ``'multi-dim multi-class'``
#     401 """
#     402 # Remove excess dimensions
# --> 403 preds, target = _input_squeeze(preds, target)
#     405 # Convert half precision tensors to full precision, as not all ops are supported
#     406 # for example, min() is not supported
#     407 if preds.dtype == torch.float16:
#
# File D:\Soft\Anaconda3\envs\DL\lib\site-packages\torchmetrics\utilities\checks.py:306, in _input_squeeze(preds, target)
#     301 def _input_squeeze(
#     302     preds: Tensor,
#     303     target: Tensor,
#     304 ) -> Tuple[Tensor, Tensor]:
#     305     """Remove excess dimensions."""
# --> 306     if preds.shape[0] == 1:
#     307         preds, target = preds.squeeze().unsqueeze(0), target.squeeze().unsqueeze(0)
#     308     else:
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
plt.figure(figsize=(10, 10))
plt.plot([0, 1], [0, 1], 'k--')

# One hot encoding
enc = OneHotEncoder()
Y_onehot = enc.fit_transform(y_test[:, np.newaxis]).toarray()

with torch.no_grad():
    y_pred = model(X_test).numpy()
    fpr, tpr, threshold = roc_curve(Y_onehot.ravel(), y_pred.ravel())
    
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc(fpr, tpr)))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend();

# %% [markdown]
# ## 3. Model(No outliers)

# %% [markdown]
# ### 3.1 Define the Model

# %%
class TabularModel(nn.Module):
    def __init__(self, input_dim):
        super(TabularModel, self).__init__()
        self.layer1 = nn.Linear(input_dim, 200)
        self.layer2 = nn.Linear(200, 300)
        self.layer3 = nn.Linear(300, 2)
        
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
model =  TabularModel(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()
model
# Out:
# TabularModel(
#   (layer1): Linear(in_features=116, out_features=200, bias=True)
#   (layer2): Linear(in_features=200, out_features=300, bias=True)
#   (layer3): Linear(in_features=300, out_features=2, bias=True)
# )

# %% [markdown]
# ### 3.2 Train the model(SMOTE)

# %%
EPOCHS  = 100

X_train = Variable(torch.from_numpy(X_train)).float()
y_train = Variable(torch.from_numpy(y_train)).long()
X_test  = Variable(torch.from_numpy(X_test)).float()
y_test  = Variable(torch.from_numpy(y_test)).long()


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()
    
    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [07:17<00:00,  4.37s/it]

# %%
plt.figure(figsize=(10, 10))
plt.plot([0, 1], [0, 1], 'k--')

# One hot encoding
enc = OneHotEncoder()
Y_onehot = enc.fit_transform(y_test[:, np.newaxis]).toarray()

with torch.no_grad():
    y_pred = model(X_test).numpy()
    fpr, tpr, threshold = roc_curve(Y_onehot.ravel(), y_pred.ravel())
    
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc(fpr, tpr)))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend();
