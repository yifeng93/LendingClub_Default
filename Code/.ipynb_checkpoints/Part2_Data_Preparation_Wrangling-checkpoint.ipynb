# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#X.-Functions" data-toc-modified-id="X.-Functions-1">X. Functions</a></span><ul class="toc-item"><li><span><a href="#X.1-missing_values_table()" data-toc-modified-id="X.1-missing_values_table()-1.1">X.1 missing_values_table()</a></span></li><li><span><a href="#X.2-drop_cols()" data-toc-modified-id="X.2-drop_cols()-1.2">X.2 drop_cols()</a></span></li><li><span><a href="#X.3-outliers_remove()" data-toc-modified-id="X.3-outliers_remove()-1.3">X.3 outliers_remove()</a></span></li></ul></li><li><span><a href="#1.-Data" data-toc-modified-id="1.-Data-2">1. Data</a></span></li><li><span><a href="#2.-Pearson-Correlation" data-toc-modified-id="2.-Pearson-Correlation-3">2. Pearson Correlation</a></span></li><li><span><a href="#3.-Outliers" data-toc-modified-id="3.-Outliers-4">3. Outliers</a></span></li><li><span><a href="#4.-EDA" data-toc-modified-id="4.-EDA-5">4. EDA</a></span></li><li><span><a href="#5.-Short-Summary" data-toc-modified-id="5.-Short-Summary-6">5. Short Summary</a></span></li></ul></div>

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ## X. Functions

# %% [markdown]
# ### X.1 missing_values_table()

# %%
# Define a function to visulize the features with missing values, and % of total values, & datatype
def missing_values_table(df):
     # Total missing values
    mis_val = df.isnull().sum()
    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_type = df.dtypes
    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent, mis_val_type], axis=1)
        
     # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values', 2: 'type'})
        
    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[ mis_val_table_ren_columns.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
        
    # Print some summary information
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n" "There are " + str(mis_val_table_ren_columns.shape[0]) + " columns that have missing values.")
        
    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %% [markdown]
# ### X.2 drop_cols()

# %%
def drop_cols(cols):
    df.drop(labels=cols, axis=1, inplace=True)

# %% [markdown]
# ### X.3 outliers_remove()

# %%
def outliers_remove(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

# %% [markdown]
# ## 1. Data

# %% [markdown]
# The data has been cleaned in Part1 in some ways, we will load the data from part1 directly and check some basic information.

# %%
df = pd.read_pickle('./Data/part1_clean_data_16_18.pkl')

# %%
df.sample(5)
# Out:
#          loan_amnt  term  int_rate  installment sub_grade home_ownership  \
# 1693641    20000.0    60     12.74       452.41        C1       MORTGAGE
# 997272     11000.0    36     10.75       358.83        B4           RENT
# 691713      8800.0    36     14.46       302.74        C4       MORTGAGE
# 939366     18900.0    60     15.99       459.52        C5           RENT
# 1012240    12400.0    36     15.31       431.74        C5       MORTGAGE
#
#          annual_inc verification_status  loan_status             purpose  ...  \
# 1693641    149000.0        Not Verified   Fully Paid    home_improvement  ...
# 997272      55000.0     Source Verified   Fully Paid  debt_consolidation  ...
# 691713      37200.0            Verified   Fully Paid  debt_consolidation  ...
# 939366      42000.0            Verified   Fully Paid  debt_consolidation  ...
# 1012240     47000.0     Source Verified  Charged Off  debt_consolidation  ...
#
#         inq_fi  total_cu_tl  inq_last_12m  mo_sin_old_il_acct  \
# 1693641    0.0          1.0           7.0               154.0
# 997272     2.0          0.0           4.0               125.0
# 691713     2.0          6.0           3.0               125.0
# 939366     0.0          0.0           1.0               185.0
# 1012240    0.0          0.0           5.0               167.0
#
#          mo_sin_old_rev_tl_op  mort_acc  pub_rec_bankruptcies  IssueDate  \
# 1693641                 245.0       6.0                   0.0 2017-02-01
# 997272                  107.0       2.0                   0.0 2016-03-01
# 691713                  136.0       1.0                   0.0 2016-05-01
# 939366                  139.0       0.0                   0.0 2017-05-01
# 1012240                 202.0       0.0                   0.0 2016-03-01
#
#          annual_inc_log  fico_score
# 1693641        5.173189       782.0
# 997272         4.740371       677.0
# 691713         4.570555       662.0
# 939366         4.623260       677.0
# 1012240        4.672107       667.0
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517582 entries, 421101 to 2260697
# Data columns (total 39 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             517582 non-null  float64
#  1   term                  517582 non-null  int8
#  2   int_rate              517582 non-null  float64
#  3   installment           517582 non-null  float64
#  4   sub_grade             517582 non-null  object
#  5   home_ownership        517582 non-null  object
#  6   annual_inc            517582 non-null  float64
#  7   verification_status   517582 non-null  object
#  8   loan_status           517582 non-null  object
#  9   purpose               517582 non-null  object
#  10  addr_state            517582 non-null  object
#  11  dti                   517582 non-null  float64
#  12  open_acc              517582 non-null  float64
#  13  pub_rec               517582 non-null  float64
#  14  revol_bal             517582 non-null  float64
#  15  revol_util            517582 non-null  float64
#  16  total_acc             517582 non-null  float64
#  17  initial_list_status   517582 non-null  object
#  18  open_acc_6m           517582 non-null  float64
#  19  open_act_il           517582 non-null  float64
#  20  open_il_12m           517582 non-null  float64
#  21  open_il_24m           517582 non-null  float64
#  22  mths_since_rcnt_il    503941 non-null  float64
#  23  total_bal_il          517582 non-null  float64
#  24  il_util               447699 non-null  float64
#  25  open_rv_12m           517582 non-null  float64
#  26  open_rv_24m           517582 non-null  float64
#  27  max_bal_bc            517582 non-null  float64
#  28  all_util              517582 non-null  float64
#  29  inq_fi                517582 non-null  float64
#  30  total_cu_tl           517582 non-null  float64
#  31  inq_last_12m          517582 non-null  float64
#  32  mo_sin_old_il_acct    503941 non-null  float64
#  33  mo_sin_old_rev_tl_op  517582 non-null  float64
#  34  mort_acc              517582 non-null  float64
#  35  pub_rec_bankruptcies  517582 non-null  float64
#  36  IssueDate             517582 non-null  datetime64[ns]
#  37  annual_inc_log        517582 non-null  float64
#  38  fico_score            517582 non-null  float64
# dtypes: datetime64[ns](1), float64(30), int8(1), object(7)
# memory usage: 154.5+ MB

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 39 columns.
# There are 3 columns that have missing values.
#                     Missing Values  % of Total Values     type
# il_util                      69883               13.5  float64
# mths_since_rcnt_il           13641                2.6  float64
# mo_sin_old_il_acct           13641                2.6  float64

# %%
drop_list = ['open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m','open_rv_24m', 'inq_last_12m','annual_inc_log']

# %%
drop_cols(drop_list)

# %% [markdown]
# ## 2. Pearson Correlation

# %% [markdown]
# For Pearson Correlation, we only use continuous variables.

# %%
list_float = df.select_dtypes(exclude=['object']).columns

# %%
list_float
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mort_acc', 'pub_rec_bankruptcies', 'IssueDate',
#        'fico_score'],
#       dtype='object')

# %% [markdown]
# Some variables not useful for Person correlation check, E.g., $IssueDate$

# %%
list_float = ['loan_amnt', 'term', 'int_rate', 'installment','annual_inc', 'dti', 
              'open_acc', 'pub_rec', 'revol_bal', 'revol_util','total_acc', 
              'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mort_acc','pub_rec_bankruptcies', 'fico_score']

# %%
plt.figure(figsize = (20,18))
sns.set(font_scale = 2.2)
heatmap = sns.heatmap(df[list_float].corr(), annot=True,
                      cmap = "coolwarm",
                      fmt=".2f",annot_kws={'size':13})

# %% [markdown]
# We see that *loan_amnt* and *installment* are highly correlated, which makes sense. Higher loan amount, more installment will be repaid each month. *loan_amnt* will be kept.  *pub_rec* and *pub_rec_bankruptcies* are highly correlated. I will keep *pub_rec_bankruptcies* only.

# %%
drop_cols(['pub_rec','installment'])

# %% [markdown]
# ## 3. Outliers

# %%
# cols = ['loan_amnt', 'term', 'int_rate', 'emp_length',
#        'annual_inc', 'dti', 'open_acc', 'revol_bal', 'revol_util',
#        'total_acc', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mort_acc',
#        'pub_rec_bankruptcies', 'fico_score'] # one or more

# Q1 = df[cols].quantile(0.25)
# Q3 = df[cols].quantile(0.75)
# IQR = Q3 - Q1

# new_df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# ## 4. EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 893580 entries, 0 to 894250
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             893580 non-null  float64
#  1   term                  893580 non-null  int8
#  2   int_rate              893580 non-null  float64
#  3   sub_grade             893580 non-null  object
#  4   emp_length            835965 non-null  float64
#  5   home_ownership        893580 non-null  object
#  6   annual_inc            893580 non-null  float64
#  7   verification_status   893580 non-null  object
#  8   loan_status           893580 non-null  object
#  9   purpose               893580 non-null  object
#  10  addr_state            893580 non-null  object
#  11  dti                   893580 non-null  float64
#  12  open_acc              893580 non-null  float64
#  13  revol_bal             893580 non-null  float64
#  14  revol_util            893015 non-null  float64
#  15  total_acc             893580 non-null  float64
#  16  initial_list_status   893580 non-null  object
#  17  mo_sin_old_il_acct    868604 non-null  float64
#  18  mo_sin_old_rev_tl_op  893580 non-null  float64
#  19  mort_acc              893580 non-null  float64
#  20  pub_rec_bankruptcies  893580 non-null  float64
#  21  IssueDate             893580 non-null  datetime64[ns]
#  22  annual_inc_log        893580 non-null  float64
#  23  fico_score            893580 non-null  float64
#  24  revol_bal_log         893580 non-null  float64
# dtypes: datetime64[ns](1), float64(16), int8(1), object(7)
# memory usage: 171.3+ MB

# %% [markdown]
# ## 5. Short Summary

# %%
drop_cols(['annual_inc_log','revol_bal_log'])

# %%
new_df.drop(labels=['annual_inc_log','revol_bal_log'], axis=1, inplace=True)
# Out:
# D:\Temp\ipykernel_1452\1541464828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(labels=['annual_inc_log','revol_bal_log'], axis=1, inplace=True)

# %%
df.to_pickle('./Data/part2_clean_data.pkl')  # where to save it, usually as a .pkl

# %%
new_df.to_pickle('./Data/part2_clean_data_NoOutliers.pkl')  # where to save it, usually as a .pkl
