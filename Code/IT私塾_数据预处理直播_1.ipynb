# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-数据初探" data-toc-modified-id="1.-数据初探-1">1. 数据初探</a></span><ul class="toc-item"><li><span><a href="#1.1-导入数据" data-toc-modified-id="1.1-导入数据-1.1">1.1 导入数据</a></span></li><li><span><a href="#1.2-关键变量" data-toc-modified-id="1.2-关键变量-1.2">1.2 关键变量</a></span></li></ul></li><li><span><a href="#2.-第一轮数据清洗" data-toc-modified-id="2.-第一轮数据清洗-2">2. 第一轮数据清洗</a></span><ul class="toc-item"><li><span><a href="#2.1-缺失值的处理" data-toc-modified-id="2.1-缺失值的处理-2.1">2.1 缺失值的处理</a></span></li><li><span><a href="#2.2-独特率" data-toc-modified-id="2.2-独特率-2.2">2.2 独特率</a></span></li></ul></li><li><span><a href="#3-第二轮数据清洗" data-toc-modified-id="3-第二轮数据清洗-3">3 第二轮数据清洗</a></span><ul class="toc-item"><li><span><a href="#3.1-异数/异常" data-toc-modified-id="3.1-异数/异常-3.1">3.1 异数/异常</a></span></li><li><span><a href="#3.2-相关系数检查" data-toc-modified-id="3.2-相关系数检查-3.2">3.2 相关系数检查</a></span></li><li><span><a href="#3.2-相关系数检查" data-toc-modified-id="3.2-相关系数检查-3.3">3.2 相关系数检查</a></span></li><li><span><a href="#3.3-One-Hot-Encoding" data-toc-modified-id="3.3-One-Hot-Encoding-3.4">3.3 One-Hot Encoding</a></span></li></ul></li></ul></div>

# %%
import pandas as pd 
import numpy as np

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. 数据初探

# %% [markdown]
# ### 1.1 导入数据

# %% [markdown]
# **载入数据**

# %%
df = pd.read_pickle('../Data/IT_2018.pkl')
# 如果是csv文件，则使用以下代码，同时，注意相对路径和绝对路径
# df = pd.read_csv('../Data/2018_test_demo.pkl')

# %% [markdown]
# **对数据集有点基本印象**

# %%
# 多少行，多少列
df.shape
# Out:
# (56311, 152)

# %%
df.info()
# 当我们的变量太多的时候，有时候pandas并不会将所有显示出来,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56311 entries, 421101 to 1611872
# Columns: 152 entries, id to IssueDate
# dtypes: datetime64[ns](1), float64(113), object(38)
# memory usage: 65.7+ MB

# %%
df.info(verbose=True, show_counts=True)
# verbose == 啰唆一点
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56311 entries, 421101 to 1611872
# Data columns (total 152 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    id                                          56311 non-null  object
#  1    member_id                                   0 non-null      float64
#  2    loan_amnt                                   56311 non-null  float64
#  3    funded_amnt                                 56311 non-null  float64
#  4    funded_amnt_inv                             56311 non-null  float64
#  5    term                                        56311 non-null  object
#  6    int_rate                                    56311 non-null  float64
#  7    installment                                 56311 non-null  float64
#  8    grade                                       56311 non-null  object
#  9    sub_grade                                   56311 non-null  object
#  10   emp_title                                   50924 non-null  object
#  11   emp_length                                  51377 non-null  object
#  12   home_ownership                              56311 non-null  object
#  13   annual_inc                                  56311 non-null  float64
#  14   verification_status                         56311 non-null  object
#  15   issue_d                                     56311 non-null  object
#  16   loan_status                                 56311 non-null  object
#  17   pymnt_plan                                  56311 non-null  object
#  18   url                                         56311 non-null  object
#  19   desc                                        0 non-null      object
#  20   purpose                                     56311 non-null  object
#  21   title                                       56311 non-null  object
#  22   zip_code                                    56311 non-null  object
#  23   addr_state                                  56311 non-null  object
#  24   dti                                         56160 non-null  float64
#  25   delinq_2yrs                                 56311 non-null  float64
#  26   earliest_cr_line                            56311 non-null  object
#  27   fico_range_low                              56311 non-null  float64
#  28   fico_range_high                             56311 non-null  float64
#  29   inq_last_6mths                              56311 non-null  float64
#  30   mths_since_last_delinq                      25200 non-null  float64
#  31   mths_since_last_record                      8324 non-null   float64
#  32   open_acc                                    56311 non-null  float64
#  33   pub_rec                                     56311 non-null  float64
#  34   revol_bal                                   56311 non-null  float64
#  35   revol_util                                  56237 non-null  float64
#  36   total_acc                                   56311 non-null  float64
#  37   initial_list_status                         56311 non-null  object
#  38   out_prncp                                   56311 non-null  float64
#  39   out_prncp_inv                               56311 non-null  float64
#  40   total_pymnt                                 56311 non-null  float64
#  41   total_pymnt_inv                             56311 non-null  float64
#  42   total_rec_prncp                             56311 non-null  float64
#  43   total_rec_int                               56311 non-null  float64
#  44   total_rec_late_fee                          56311 non-null  float64
#  45   recoveries                                  56311 non-null  float64
#  46   collection_recovery_fee                     56311 non-null  float64
#  47   last_pymnt_d                                55773 non-null  object
#  48   last_pymnt_amnt                             56311 non-null  float64
#  49   next_pymnt_d                                0 non-null      object
#  50   last_credit_pull_d                          56309 non-null  object
#  51   last_fico_range_high                        56311 non-null  float64
#  52   last_fico_range_low                         56311 non-null  float64
#  53   collections_12_mths_ex_med                  56311 non-null  float64
#  54   mths_since_last_major_derog                 13626 non-null  float64
#  55   policy_code                                 56311 non-null  float64
#  56   application_type                            56311 non-null  object
#  57   annual_inc_joint                            7086 non-null   float64
#  58   dti_joint                                   7086 non-null   float64
#  59   verification_status_joint                   6882 non-null   object
#  60   acc_now_delinq                              56311 non-null  float64
#  61   tot_coll_amt                                56311 non-null  float64
#  62   tot_cur_bal                                 56311 non-null  float64
#  63   open_acc_6m                                 56311 non-null  float64
#  64   open_act_il                                 56311 non-null  float64
#  65   open_il_12m                                 56311 non-null  float64
#  66   open_il_24m                                 56311 non-null  float64
#  67   mths_since_rcnt_il                          54443 non-null  float64
#  68   total_bal_il                                56311 non-null  float64
#  69   il_util                                     46946 non-null  float64
#  70   open_rv_12m                                 56311 non-null  float64
#  71   open_rv_24m                                 56311 non-null  float64
#  72   max_bal_bc                                  56311 non-null  float64
#  73   all_util                                    56296 non-null  float64
#  74   total_rev_hi_lim                            56311 non-null  float64
#  75   inq_fi                                      56311 non-null  float64
#  76   total_cu_tl                                 56311 non-null  float64
#  77   inq_last_12m                                56311 non-null  float64
#  78   acc_open_past_24mths                        56311 non-null  float64
#  79   avg_cur_bal                                 56306 non-null  float64
#  80   bc_open_to_buy                              55355 non-null  float64
#  81   bc_util                                     55313 non-null  float64
#  82   chargeoff_within_12_mths                    56311 non-null  float64
#  83   delinq_amnt                                 56311 non-null  float64
#  84   mo_sin_old_il_acct                          54443 non-null  float64
#  85   mo_sin_old_rev_tl_op                        56311 non-null  float64
#  86   mo_sin_rcnt_rev_tl_op                       56311 non-null  float64
#  87   mo_sin_rcnt_tl                              56311 non-null  float64
#  88   mort_acc                                    56311 non-null  float64
#  89   mths_since_recent_bc                        55425 non-null  float64
#  90   mths_since_recent_bc_dlq                    11605 non-null  float64
#  91   mths_since_recent_inq                       51610 non-null  float64
#  92   mths_since_recent_revol_delinq              16691 non-null  float64
#  93   num_accts_ever_120_pd                       56311 non-null  float64
#  94   num_actv_bc_tl                              56311 non-null  float64
#  95   num_actv_rev_tl                             56311 non-null  float64
#  96   num_bc_sats                                 56311 non-null  float64
#  97   num_bc_tl                                   56311 non-null  float64
#  98   num_il_tl                                   56311 non-null  float64
#  99   num_op_rev_tl                               56311 non-null  float64
#  100  num_rev_accts                               56311 non-null  float64
#  101  num_rev_tl_bal_gt_0                         56311 non-null  float64
#  102  num_sats                                    56311 non-null  float64
#  103  num_tl_120dpd_2m                            54772 non-null  float64
#  104  num_tl_30dpd                                56311 non-null  float64
#  105  num_tl_90g_dpd_24m                          56311 non-null  float64
#  106  num_tl_op_past_12m                          56311 non-null  float64
#  107  pct_tl_nvr_dlq                              56310 non-null  float64
#  108  percent_bc_gt_75                            55354 non-null  float64
#  109  pub_rec_bankruptcies                        56311 non-null  float64
#  110  tax_liens                                   56311 non-null  float64
#  111  tot_hi_cred_lim                             56311 non-null  float64
#  112  total_bal_ex_mort                           56311 non-null  float64
#  113  total_bc_limit                              56311 non-null  float64
#  114  total_il_high_credit_limit                  56311 non-null  float64
#  115  revol_bal_joint                             7086 non-null   float64
#  116  sec_app_fico_range_low                      7086 non-null   float64
#  117  sec_app_fico_range_high                     7086 non-null   float64
#  118  sec_app_earliest_cr_line                    7086 non-null   object
#  119  sec_app_inq_last_6mths                      7086 non-null   float64
#  120  sec_app_mort_acc                            7086 non-null   float64
#  121  sec_app_open_acc                            7086 non-null   float64
#  122  sec_app_revol_util                          6946 non-null   float64
#  123  sec_app_open_act_il                         7086 non-null   float64
#  124  sec_app_num_rev_accts                       7086 non-null   float64
#  125  sec_app_chargeoff_within_12_mths            7086 non-null   float64
#  126  sec_app_collections_12_mths_ex_med          7086 non-null   float64
#  127  sec_app_mths_since_last_major_derog         2460 non-null   float64
#  128  hardship_flag                               56311 non-null  object
#  129  hardship_type                               25 non-null     object
#  130  hardship_reason                             25 non-null     object
#  131  hardship_status                             25 non-null     object
#  132  deferral_term                               25 non-null     float64
#  133  hardship_amount                             25 non-null     float64
#  134  hardship_start_date                         25 non-null     object
#  135  hardship_end_date                           25 non-null     object
#  136  payment_plan_start_date                     25 non-null     object
#  137  hardship_length                             25 non-null     float64
#  138  hardship_dpd                                25 non-null     float64
#  139  hardship_loan_status                        25 non-null     object
#  140  orig_projected_additional_accrued_interest  5 non-null      float64
#  141  hardship_payoff_balance_amount              25 non-null     float64
#  142  hardship_last_payment_amount                25 non-null     float64
#  143  disbursement_method                         56311 non-null  object
#  144  debt_settlement_flag                        56311 non-null  object
#  145  debt_settlement_flag_date                   409 non-null    object
#  146  settlement_status                           409 non-null    object
#  147  settlement_date                             409 non-null    object
#  148  settlement_amount                           409 non-null    float64
#  149  settlement_percentage                       409 non-null    float64
#  150  settlement_term                             409 non-null    float64
#  151  IssueDate                                   56311 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(113), object(38)
# memory usage: 65.7+ MB

# %%
# 随机显示5行数据
df.sample(5)
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 446838  100065804        NaN     6000.0       6000.0           6000.0
# 799941  139041816        NaN    12000.0      12000.0          12000.0
# 521917  126639279        NaN    14000.0      14000.0          14000.0
# 468066  128780648        NaN    20000.0      20000.0          20000.0
# 868753  136362744        NaN    16000.0      16000.0          16000.0
#
#               term  int_rate  installment grade sub_grade  ...  \
# 446838   36 months      9.92       193.38     B        B2  ...
# 799941   60 months     18.94       310.90     D        D2  ...
# 521917   60 months     10.42       300.37     B        B3  ...
# 468066   36 months     16.01       703.24     C        C5  ...
# 868753   36 months      8.46       504.79     A        A5  ...
#
#        hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 446838                          NaN                Cash                    N
# 799941                          NaN                Cash                    N
# 521917                          NaN                Cash                    N
# 468066                          NaN                Cash                    N
# 868753                          NaN                Cash                    N
#
#         debt_settlement_flag_date settlement_status settlement_date  \
# 446838                        NaN               NaN             NaN
# 799941                        NaN               NaN             NaN
# 521917                        NaN               NaN             NaN
# 468066                        NaN               NaN             NaN
# 868753                        NaN               NaN             NaN
#
#        settlement_amount settlement_percentage settlement_term  IssueDate
# 446838               NaN                   NaN             NaN 2018-03-01
# 799941               NaN                   NaN             NaN 2018-08-01
# 521917               NaN                   NaN             NaN 2018-01-01
# 468066               NaN                   NaN             NaN 2018-02-01
# 868753               NaN                   NaN             NaN 2018-07-01
#
# [5 rows x 152 columns]

# %% [markdown]
# ### 1.2 关键变量

# %%
df['loan_status'].value_counts(normalize=True)
# Out:
# Fully Paid     0.842535
# Charged Off    0.157465
# Name: loan_status, dtype: float64

# %%
# 更改某一个变量里的值或者多个值
df["loan_status"].replace({"Fully Paid": "付清", "Charged Off": "违约"}, inplace=True)

# %%
df['loan_status'].value_counts(normalize=False)
# Out:
# 付清    47444
# 违约     8867
# Name: loan_status, dtype: int64

# %%
# 有些同学的jupyter notebook并未对matplotlib和seaborn进行中文设置。可能会导致乱码，此处我们先全保持英文命名
df["loan_status"].replace({"付清": "Fully Paid", "违约": "Charged Off"}, inplace=True)

# %%
# 查看我们的关键变量是否有缺失
df['loan_status'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 2. 第一轮数据清洗

# %% [markdown]
# ### 2.1 缺失值的处理

# %% [markdown]
# 通常情况下，Pandas或者numpy里的缺失值是用NaN或者NA来表示的。但也要小心，有一些特定的数据会有不同的缺失值表示，比如9999。

# %%
# pandas自带的缺失值数量求和
df.isnull().sum()
# Out:
# id                           0
# member_id                56311
# loan_amnt                    0
# funded_amnt                  0
# funded_amnt_inv              0
#                          ...
# settlement_date          55902
# settlement_amount        55902
# settlement_percentage    55902
# settlement_term          55902
# IssueDate                    0
# Length: 152, dtype: int64

# %%
df.isnull().mean()
# Out:
# id                       0.000000
# member_id                1.000000
# loan_amnt                0.000000
# funded_amnt              0.000000
# funded_amnt_inv          0.000000
#                            ...
# settlement_date          0.992737
# settlement_amount        0.992737
# settlement_percentage    0.992737
# settlement_term          0.992737
# IssueDate                0.000000
# Length: 152, dtype: float64

# %%
# 只要有空位，都算缺失。所以这里有非常多，比我们的行数还多。
df.isnull().sum().sum()
# Out:
# 2325293

# %% [markdown]
# **有没有一种方式，能输入一个dataframe,然后直接输出一个表格，包含变量的缺失值和缺失率呢？**

# %%
# Define a function to visulize the features with missing values, and % of total values, & datatype
def missing_values_table(df):
     # Total missing values
    mis_val = df.isnull().sum()
    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_type = df.dtypes
    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent, mis_val_type], axis=1)
        
     # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values', 2: 'type'})
        
    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[ mis_val_table_ren_columns.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
        
    # Print some summary information
    print ("你所选择的数据有 " + str(df.shape[1]) + " 列.\n" "其中有 " + str(mis_val_table_ren_columns.shape[0]) + " 列的变量是有缺失值的.")
        
    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
missing_values_table(df)
# Out:
# 你所选择的数据有 152 列.
# 其中有 62 列的变量是有缺失值的.
#                                             Missing Values  % of Total Values  \
# member_id                                            56311              100.0
# desc                                                 56311              100.0
# next_pymnt_d                                         56311              100.0
# orig_projected_additional_accrued_interest           56306              100.0
# hardship_dpd                                         56286              100.0
# hardship_length                                      56286              100.0
# hardship_status                                      56286              100.0
# deferral_term                                        56286              100.0
# hardship_amount                                      56286              100.0
# hardship_start_date                                  56286              100.0
# hardship_end_date                                    56286              100.0
# payment_plan_start_date                              56286              100.0
# hardship_reason                                      56286              100.0
# hardship_loan_status                                 56286              100.0
# hardship_type                                        56286              100.0
# hardship_payoff_balance_amount                       56286              100.0
# hardship_last_payment_amount                         56286              100.0
# settlement_date                                      55902               99.3
# settlement_percentage                                55902               99.3
# debt_settlement_flag_date                            55902               99.3
# settlement_status                                    55902               99.3
# settlement_amount                                    55902               99.3
# settlement_term                                      55902               99.3
# sec_app_mths_since_last_major_derog                  53851               95.6
# verification_status_joint                            49429               87.8
# sec_app_revol_util                                   49365               87.7
# sec_app_earliest_cr_line                             49225               87.4
# sec_app_num_rev_accts                                49225               87.4
# sec_app_open_act_il                                  49225               87.4
# sec_app_open_acc                                     49225               87.4
# sec_app_mort_acc                                     49225               87.4
# sec_app_inq_last_6mths                               49225               87.4
# sec_app_fico_range_high                              49225               87.4
# sec_app_collections_12_mths_ex_med                   49225               87.4
# sec_app_fico_range_low                               49225               87.4
# revol_bal_joint                                      49225               87.4
# dti_joint                                            49225               87.4
# annual_inc_joint                                     49225               87.4
# sec_app_chargeoff_within_12_mths                     49225               87.4
# mths_since_last_record                               47987               85.2
# mths_since_recent_bc_dlq                             44706               79.4
# mths_since_last_major_derog                          42685               75.8
# mths_since_recent_revol_delinq                       39620               70.4
# mths_since_last_delinq                               31111               55.2
# il_util                                               9365               16.6
# emp_title                                             5387                9.6
# emp_length                                            4934                8.8
# mths_since_recent_inq                                 4701                8.3
# mo_sin_old_il_acct                                    1868                3.3
# mths_since_rcnt_il                                    1868                3.3
# num_tl_120dpd_2m                                      1539                2.7
# bc_util                                                998                1.8
# percent_bc_gt_75                                       957                1.7
# bc_open_to_buy                                         956                1.7
# mths_since_recent_bc                                   886                1.6
# last_pymnt_d                                           538                1.0
# dti                                                    151                0.3
# revol_util                                              74                0.1
# all_util                                                15                0.0
# avg_cur_bal                                              5                0.0
# last_credit_pull_d                                       2                0.0
# pct_tl_nvr_dlq                                           1                0.0
#
#                                                type
# member_id                                   float64
# desc                                         object
# next_pymnt_d                                 object
# orig_projected_additional_accrued_interest  float64
# hardship_dpd                                float64
# hardship_length                             float64
# hardship_status                              object
# deferral_term                               float64
# hardship_amount                             float64
# hardship_start_date                          object
# hardship_end_date                            object
# payment_plan_start_date                      object
# hardship_reason                              object
# hardship_loan_status                         object
# hardship_type                                object
# hardship_payoff_balance_amount              float64
# hardship_last_payment_amount                float64
# settlement_date                              object
# settlement_percentage                       float64
# debt_settlement_flag_date                    object
# settlement_status                            object
# settlement_amount                           float64
# settlement_term                             float64
# sec_app_mths_since_last_major_derog         float64
# verification_status_joint                    object
# sec_app_revol_util                          float64
# sec_app_earliest_cr_line                     object
# sec_app_num_rev_accts                       float64
# sec_app_open_act_il                         float64
# sec_app_open_acc                            float64
# sec_app_mort_acc                            float64
# sec_app_inq_last_6mths                      float64
# sec_app_fico_range_high                     float64
# sec_app_collections_12_mths_ex_med          float64
# sec_app_fico_range_low                      float64
# revol_bal_joint                             float64
# dti_joint                                   float64
# annual_inc_joint                            float64
# sec_app_chargeoff_within_12_mths            float64
# mths_since_last_record                      float64
# mths_since_recent_bc_dlq                    float64
# mths_since_last_major_derog                 float64
# mths_since_recent_revol_delinq              float64
# mths_since_last_delinq                      float64
# il_util                                     float64
# emp_title                                    object
# emp_length                                   object
# mths_since_recent_inq                       float64
# mo_sin_old_il_acct                          float64
# mths_since_rcnt_il                          float64
# num_tl_120dpd_2m                            float64
# bc_util                                     float64
# percent_bc_gt_75                            float64
# bc_open_to_buy                              float64
# mths_since_recent_bc                        float64
# last_pymnt_d                                 object
# dti                                         float64
# revol_util                                  float64
# all_util                                    float64
# avg_cur_bal                                 float64
# last_credit_pull_d                           object
# pct_tl_nvr_dlq                              float64

# %% [markdown]
# **咱们就以50%为界限，如果一个变量有超过50%的缺失的话，我们就将其抛弃**

# %%
missing_frac = df.isnull().mean()
drop_list = sorted(missing_frac[missing_frac > 0.50].index)

# %%
len(drop_list)
# Out:
# 44

# %%
# 最常见的删除变量的方式
# df.drop(labels=["a","b","c"], axis=1, inplace=True)

# %%
# 定义一个删除变量的函数，只要把要删除的变量列表放进去就行，方便之后使用
def drop_cols(cols):
    df.drop(labels=cols, axis=1, inplace=True)

# %%
drop_cols(drop_list)

# %% [markdown]
# **下一步可以根据自己的需要删除一些变量，这一步的主观性比较强**
# **这里我选择的变量基于的理由是：这些信息是贷款拿到之后才有的信息，对实际操作指导意义不大**

# %%
drop_list = ['acc_now_delinq', 'acc_open_past_24mths','avg_cur_bal', 
             'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 
             'collection_recovery_fee', 'collections_12_mths_ex_med', 
             'debt_settlement_flag', 'delinq_2yrs', 'delinq_amnt', 'disbursement_method', 
             'funded_amnt', 'funded_amnt_inv', 'hardship_flag', 'inq_last_6mths', 'last_credit_pull_d', 
             'last_fico_range_high', 'last_fico_range_low', 'last_pymnt_amnt', 'last_pymnt_d', 
             'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mths_since_recent_bc', 'mths_since_recent_inq', 
             'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 
             'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 
             'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',  'out_prncp', 'out_prncp_inv',
             'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pymnt_plan', 'recoveries', 'tax_liens', 'tot_coll_amt', 
             'tot_cur_bal', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 
             'total_pymnt', 'total_pymnt_inv', 'total_rec_int', 'total_rec_late_fee', 'total_rec_prncp', 
             'total_rev_hi_lim','earliest_cr_line']

# %%
drop_cols(drop_list)

# %%
missing_values_table(df)
# Out:
# 你所选择的数据有 49 列.
# 其中有 8 列的变量是有缺失值的.
#                     Missing Values  % of Total Values     type
# il_util                       9365               16.6  float64
# emp_title                     5387                9.6   object
# emp_length                    4934                8.8   object
# mths_since_rcnt_il            1868                3.3  float64
# mo_sin_old_il_acct            1868                3.3  float64
# dti                            151                0.3  float64
# revol_util                      74                0.1  float64
# all_util                        15                0.0  float64

# %%
# 删除行，具有缺失值的行
def drop_null_row(cols):
    df.dropna(subset=cols, axis=0, inplace=True)

# %%
drop_list = ['all_util', 'revol_util', 'dti']

# %%
drop_null_row(drop_list)

# %%
missing_values_table(df)
# Out:
# 你所选择的数据有 49 列.
# 其中有 5 列的变量是有缺失值的.
#                     Missing Values  % of Total Values     type
# il_util                       9297               16.6  float64
# emp_title                     5227                9.3   object
# emp_length                    4775                8.5   object
# mths_since_rcnt_il            1850                3.3  float64
# mo_sin_old_il_acct            1850                3.3  float64

# %% [markdown]
# ### 2.2 独特率

# %% [markdown]
# **这里我们不能再使用一个比例来剔除独特率高或者低的变量了，因为对于不同的变量，独特率高或者低都有可能是正常的**

# %%
df.nunique()
# Out:
# id                      56086
# loan_amnt                1304
# term                        2
# int_rate                  110
# installment             12281
# grade                       7
# sub_grade                  35
# emp_title               22398
# emp_length                 11
# home_ownership              4
# annual_inc               5628
# verification_status         3
# issue_d                    12
# loan_status                 2
# url                     56086
# purpose                    13
# title                      12
# zip_code                  868
# addr_state                 50
# dti                      5195
# fico_range_low             38
# fico_range_high            38
# open_acc                   59
# pub_rec                     9
# revol_bal               26507
# revol_util               1050
# total_acc                 110
# initial_list_status         2
# policy_code                 1
# application_type            2
# open_acc_6m                13
# open_act_il                39
# open_il_12m                 7
# open_il_24m                17
# mths_since_rcnt_il        222
# total_bal_il            37113
# il_util                   175
# open_rv_12m                20
# open_rv_24m                30
# max_bal_bc              15146
# all_util                  139
# inq_fi                     26
# total_cu_tl                40
# inq_last_12m               39
# mo_sin_old_il_acct        392
# mo_sin_old_rev_tl_op      641
# mort_acc                   20
# pub_rec_bankruptcies        4
# IssueDate                  12
# dtype: int64

# %% [markdown]
# 我们可以看出， id和url拥有着100%的独特率。然后再结合其定义，会发现这个变量对模型是没有什么帮助的。

# %%
drop_list = ['id', 'emp_title', 'url', 'initial_list_status', 'policy_code', 'application_type']

# %%
drop_cols(drop_list)

# %% [markdown]
# ## 3 第二轮数据清洗

# %% [markdown]
# 目前我们已经从152个变量缩减为45个变量了。那么就要进行稍微精细化的一些处理了

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56086 entries, 421101 to 1611872
# Data columns (total 43 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             56086 non-null  float64
#  1   term                  56086 non-null  object
#  2   int_rate              56086 non-null  float64
#  3   installment           56086 non-null  float64
#  4   grade                 56086 non-null  object
#  5   sub_grade             56086 non-null  object
#  6   emp_length            51311 non-null  object
#  7   home_ownership        56086 non-null  object
#  8   annual_inc            56086 non-null  float64
#  9   verification_status   56086 non-null  object
#  10  issue_d               56086 non-null  object
#  11  loan_status           56086 non-null  object
#  12  purpose               56086 non-null  object
#  13  title                 56086 non-null  object
#  14  zip_code              56086 non-null  object
#  15  addr_state            56086 non-null  object
#  16  dti                   56086 non-null  float64
#  17  fico_range_low        56086 non-null  float64
#  18  fico_range_high       56086 non-null  float64
#  19  open_acc              56086 non-null  float64
#  20  pub_rec               56086 non-null  float64
#  21  revol_bal             56086 non-null  float64
#  22  revol_util            56086 non-null  float64
#  23  total_acc             56086 non-null  float64
#  24  open_acc_6m           56086 non-null  float64
#  25  open_act_il           56086 non-null  float64
#  26  open_il_12m           56086 non-null  float64
#  27  open_il_24m           56086 non-null  float64
#  28  mths_since_rcnt_il    54236 non-null  float64
#  29  total_bal_il          56086 non-null  float64
#  30  il_util               46789 non-null  float64
#  31  open_rv_12m           56086 non-null  float64
#  32  open_rv_24m           56086 non-null  float64
#  33  max_bal_bc            56086 non-null  float64
#  34  all_util              56086 non-null  float64
#  35  inq_fi                56086 non-null  float64
#  36  total_cu_tl           56086 non-null  float64
#  37  inq_last_12m          56086 non-null  float64
#  38  mo_sin_old_il_acct    54236 non-null  float64
#  39  mo_sin_old_rev_tl_op  56086 non-null  float64
#  40  mort_acc              56086 non-null  float64
#  41  pub_rec_bankruptcies  56086 non-null  float64
#  42  IssueDate             56086 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(30), object(12)
# memory usage: 18.8+ MB

# %% [markdown]
# ### 3.1 异数/异常

# %% [markdown]
# 有些人会在这里直接做相关系数检查，我个人倾向于在剩余变量不是那么多的情况下，一个一个排查，然后进行精细化处理。 最后再做相关系数检查。

# %% [markdown]
# 最常规的检查方式是这样的

# %%
df.boxplot(column=['loan_amnt'])
# Out:
# <AxesSubplot:>

# %%
df.hist(column=['loan_amnt'])
# Out:
# array([[<AxesSubplot:title={'center':'loan_amnt'}>]], dtype=object)

# %% [markdown]
# 我们是否可以将几个放在同一个图里面呢？ 其实是可以的，但是我并不推荐，除非你设置不同的y轴，否则无法进行对比

# %%
df.boxplot(column=['loan_amnt', 'int_rate'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# **那么是否有更聪明的方式，或者更好看的图来供我们研究呢？**
# **比如我们想要在研究每一个变量的时候，同时展示他们的分布图，盒子图，密度图，同时还要进行分组**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)

sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Yanxia Li
# make general plots to examine each feature
def plot_var(col_name, full_name, continuous):
    
    fig, (ax1, ax2) = plt.subplots(1, 2, sharex=False, figsize=(15,3))
    # plot1: counts distribution of the variable
    
    if continuous:  
        sns.histplot(df.loc[df[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(df[col_name], order=sorted(df[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(full_name)
    ax1.set_ylabel('Count')
    ax1.set_title(full_name)

          
    # plot2: bar plot of the variable grouped by loan_status
    if continuous:
        sns.boxplot(x=col_name, y='loan_status', data=df, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(full_name + ' by Loan Status')
    else:
        Charged_Off_rates = df.groupby(col_name)['loan_status'].value_counts(normalize=True)[:,'Charged Off']
        sns.barplot(x=Charged_Off_rates.index, y=Charged_Off_rates.values, color='#5975A4', saturation=1, ax=ax2)
        ax2.set_ylabel('Fraction of Loans Charged Off')
        ax2.set_title('Charged Off Rate by ' + full_name)
        ax2.set_xlabel(full_name)
    
    # plot3: kde plot of the variable gropued by loan_status
    if continuous:  
        facet = sns.FacetGrid(df, hue = 'loan_status', height=3, aspect=4)
        facet.map(sns.kdeplot, col_name, shade=True)
        #facet.set(xlim=(df[col_name].min(), df[col_name].max()))
        facet.add_legend()  
    else:
        fig = plt.figure(figsize=(12,3))
        sns.countplot(x=col_name, hue='loan_status', data=df, order=sorted(df[col_name].unique()) )
     
    plt.tight_layout()

# %%
plot_var('loan_amnt', 'loan amount', continuous=True)

# %%
plot_var('int_rate', 'interest rate', continuous=True)
# 此处我们明显发现利率越高的组，平均的违约率也是越高的。

# %%
plot_var('grade', 'grade', continuous=False)
# Out:
# D:\Soft\Anaconda3\envs\DL\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plot_var('dti', 'DTI ratio', continuous=True)

# %%
plot_var('annual_inc', 'annual income', continuous=True)

# %%
df['annual_inc_log'] = df['annual_inc'].apply(lambda x:np.log10(x+1))

# %%
plot_var('annual_inc_log', 'Log10 Annual income', continuous=True)

# %%
def outliers_to_null(variable, df):
    for x in [variable]:
        q75,q25 = np.percentile(df.loc[:,x],[75,25])
        intr_qr = q75-q25
 
        max = q75+(1.5*intr_qr)
        min = q25-(1.5*intr_qr)
 
        df.loc[df[x] < min,x] = np.nan
        df.loc[df[x] > max,x] = np.nan

# %%
outliers_to_null('annual_inc_log', df)

# %%
outliers_to_null('int_rate', df)

# %%
plot_var('annual_inc_log', 'Log10 Annual income', continuous=True)

# %%
plot_var('int_rate', 'interest rate', continuous=True)

# %% [markdown]
# ### 3.2 相关系数检查

# %%
# 只选择数字型的变量
list_float = df.select_dtypes(exclude=['object']).columns

# %%
list_float
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'fico_range_low', 'fico_range_high', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'open_acc_6m', 'open_act_il', 'open_il_12m',
#        'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mort_acc', 'pub_rec_bankruptcies', 'IssueDate',
#        'annual_inc_log'],
#       dtype='object')

# %%
plt.figure(figsize = (20,20))
sns.set(font_scale = 2.2)
pearson_correlation = sns.heatmap(df[list_float].corr(), annot=True,
                      cmap = "coolwarm",
                      fmt=".2f",annot_kws={'size':13})

# %%
drop_list = ['annual_inc', 'pub_rec_bankruptcies', 'installment']

# %%
drop_cols(drop_list)

# %% [markdown]
# 虽然我们每一步都做得比较简易，但是到目前为止， 我们已经做了数据清洗的大部分工作了。
# 我在这里略过了一对一的很多数据处理，比如 emp_length. 为了课程简易，我们先将一部分变量扔掉。继续我们的教学。

# %%
drop_list = ['sub_grade','emp_length', 'issue_d', 'title', 'zip_code', 'addr_state',
            'fico_range_low', 'open_acc_6m','open_act_il', 'open_il_12m', 'open_rv_24m']
drop_cols(drop_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56086 entries, 421101 to 1611872
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             56086 non-null  float64
#  1   term                  56086 non-null  object
#  2   int_rate              55289 non-null  float64
#  3   grade                 56086 non-null  object
#  4   home_ownership        56086 non-null  object
#  5   verification_status   56086 non-null  object
#  6   loan_status           56086 non-null  object
#  7   purpose               56086 non-null  object
#  8   dti                   56086 non-null  float64
#  9   fico_range_high       56086 non-null  float64
#  10  open_acc              56086 non-null  float64
#  11  pub_rec               56086 non-null  float64
#  12  revol_bal             56086 non-null  float64
#  13  revol_util            56086 non-null  float64
#  14  total_acc             56086 non-null  float64
#  15  open_il_24m           56086 non-null  float64
#  16  mths_since_rcnt_il    54236 non-null  float64
#  17  total_bal_il          56086 non-null  float64
#  18  il_util               46789 non-null  float64
#  19  open_rv_12m           56086 non-null  float64
#  20  max_bal_bc            56086 non-null  float64
#  21  all_util              56086 non-null  float64
#  22  inq_fi                56086 non-null  float64
#  23  total_cu_tl           56086 non-null  float64
#  24  inq_last_12m          56086 non-null  float64
#  25  mo_sin_old_il_acct    54236 non-null  float64
#  26  mo_sin_old_rev_tl_op  56086 non-null  float64
#  27  mort_acc              56086 non-null  float64
#  28  IssueDate             56086 non-null  datetime64[ns]
#  29  annual_inc_log        54633 non-null  float64
# dtypes: datetime64[ns](1), float64(23), object(6)
# memory usage: 13.3+ MB

# %%
df.to_pickle('../Data/IT_2018_数据处理.pkl')
